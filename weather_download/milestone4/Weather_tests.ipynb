# %%
cols = {
  "Address_Berlin" : "Berlin",
  "Latitude_Berlin" : "52.516",
  "Longitude_Berlin" : "13.3769",
  "Resolved_Address_Berlin" : "Berlin",
  "Name_Berlin" : "Berlin",
  "Wind_Direction_Berlin" : "99.44666666666667",
  "Temperature_Berlin" : "4.293333333333333",
  "Wind_Speed_Berlin" : "7.563333333333333",
  "Cloud_Cover_Berlin" : "100.0",
  "Heat_Index_Berlin" : "nan",
  "Chance_Precipitation_____Berlin" : "90.5",
  "Precipitation_Berlin" : "0.0016666666666666635",
  "Sea_Level_Pressure_Berlin" : "1004.0",
  "Snow_Depth_Berlin" : "0.0",
  "Snow_Berlin" : "0.0",
  "Relative_Humidity_Berlin" : "96.62166666666666",
  "Wind_Gust_Berlin" : "16.51",
  "Wind_Chill_Berlin" : "2.4033333333333333",
  "Conditions_Berlin" : "Rain, Overcast",
  "Date_time" : "2022-12-23 20:59:00",
  "Address_Hamburg" : "Hamburg",
  "Latitude_Hamburg" : "53.5537",
  "Longitude_Hamburg" : "9.99183",
  "Resolved_Address_Hamburg" : "Hamburg",
  "Name_Hamburg" : "Hamburg",
  "Wind_Direction_Hamburg" : "86.58",
  "Temperature_Hamburg" : "4.898333333333333",
  "Wind_Speed_Hamburg" : "8.3",
  "Cloud_Cover_Hamburg" : "100.0",
  "Heat_Index_Hamburg" : "nan",
  "Chance_Precipitation_____Hamburg" : "81.0",
  "Precipitation_Hamburg" : "0.295",
  "Sea_Level_Pressure_Hamburg" : "1002.0",
  "Snow_Depth_Hamburg" : "0.0",
  "Snow_Hamburg" : "0.0",
  "Relative_Humidity_Hamburg" : "96.61",
  "Wind_Gust_Hamburg" : "17.293333333333333",
  "Wind_Chill_Hamburg" : "2.8983333333333334",
  "Conditions_Hamburg" : "Rain, Overcast",
  "Address_Bremen" : "Bremen",
  "Latitude_Bremen" : "53.0754",
  "Longitude_Bremen" : "8.80454",
  "Resolved_Address_Bremen" : "Bremen",
  "Name_Bremen" : "Bremen",
  "Wind_Direction_Bremen" : "79.89666666666666",
  "Temperature_Bremen" : "5.601666666666667",
  "Wind_Speed_Bremen" : "11.241666666666667",
  "Cloud_Cover_Bremen" : "100.0",
  "Heat_Index_Bremen" : "nan",
  "Chance_Precipitation_____Bremen" : "95.2",
  "Precipitation_Bremen" : "1.705",
  "Sea_Level_Pressure_Bremen" : "1001.0",
  "Snow_Depth_Bremen" : "0.0",
  "Snow_Bremen" : "0.0",
  "Relative_Humidity_Bremen" : "95.9",
  "Wind_Gust_Bremen" : "23.0",
  "Wind_Chill_Bremen" : "3.095",
  "Conditions_Bremen" : "Rain, Overcast"
}

# %%
for key in cols.keys():
    cols[key] = "STRING"

# %%
str(cols).replace("'", "").replace(":", "")
# Out:
# '{Address_Berlin STRING, Latitude_Berlin STRING, Longitude_Berlin STRING, Resolved_Address_Berlin STRING, Name_Berlin STRING, Wind_Direction_Berlin STRING, Temperature_Berlin STRING, Wind_Speed_Berlin STRING, Cloud_Cover_Berlin STRING, Heat_Index_Berlin STRING, Chance_Precipitation_____Berlin STRING, Precipitation_Berlin STRING, Sea_Level_Pressure_Berlin STRING, Snow_Depth_Berlin STRING, Snow_Berlin STRING, Relative_Humidity_Berlin STRING, Wind_Gust_Berlin STRING, Wind_Chill_Berlin STRING, Conditions_Berlin STRING, Date_time STRING, Address_Hamburg STRING, Latitude_Hamburg STRING, Longitude_Hamburg STRING, Resolved_Address_Hamburg STRING, Name_Hamburg STRING, Wind_Direction_Hamburg STRING, Temperature_Hamburg STRING, Wind_Speed_Hamburg STRING, Cloud_Cover_Hamburg STRING, Heat_Index_Hamburg STRING, Chance_Precipitation_____Hamburg STRING, Precipitation_Hamburg STRING, Sea_Level_Pressure_Hamburg STRING, Snow_Depth_Hamburg STRING, Snow_Hamburg STRING, Relative_Humidity_Hamburg STRING, W
# ...

# %%
values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-0234f1d70131> in <module>
# ----> 1 values
#
# NameError: name 'values' is not defined
